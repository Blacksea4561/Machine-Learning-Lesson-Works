# %% [markdown]
# # Multiple Linear Regression and Regression  Error Metrics

# %%
# biz cevap ve data yı verecez  model bize tahminlerde bulunacak
# 2 + 2= 4 hesap  makinası  bize bunu verir.
#ML de ise biz sadece   data yı veriyoruz  ne yapacağı  ne bulacağı  kendisi işlemeleri  seçip  yapıyor.
# elimizde artık   birden fazla  feature  var x1, x2, x3

# %%
simple linear regression = b0 + b1 * X
Multiple linear regression = b0 + b1X1 + b2X2 + b3*X3+ .............
X1 = TV
X2 = radio
X3 = newspaper

# %% [markdown]
# # import  library

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats #pip install scipy

plt.rcParams["figure.figsize"] = (10, 6)

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("Advertising.csv")
df
# Out:
#         TV  radio  newspaper  sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   radio      200 non-null    float64
#  2   newspaper  200 non-null    float64
#  3   sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
df.shape
# Out:
# (200, 4)

# %%
df.isnull()
# Out:
#         TV  radio  newspaper  sales
# 0    False  False      False  False
# 1    False  False      False  False
# 2    False  False      False  False
# 3    False  False      False  False
# 4    False  False      False  False
# ..     ...    ...        ...    ...
# 195  False  False      False  False
# 196  False  False      False  False
# 197  False  False      False  False
# 198  False  False      False  False
# 199  False  False      False  False
#
# [200 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# TV           0
# radio        0
# newspaper    0
# sales        0
# dtype: int64

# %%
# !pip install missingno
# Out:
# Collecting missingno
#   Using cached missingno-0.5.1-py3-none-any.whl (8.7 kB)
# Requirement already satisfied: numpy in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from missingno) (1.23.4)
# Requirement already satisfied: matplotlib in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from missingno) (3.6.2)
# Requirement already satisfied: scipy in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from missingno) (1.10.1)
# Requirement already satisfied: seaborn in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from missingno) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (1.0.6)
# Requirement already satisfied: cycler>=0.10 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (9.3.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: pandas>=0.25 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from seaborn->missingno) (1.5.1)
# Requirement already satisfied: pytz>=2020.1 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.25->seaborn->missingno) (2022.6)
# Requirement already satisfied: six>=1.5 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)
# Installing collected packages: missingno
# Successfully installed missingno-0.5.1
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import missingno as msno

# %%
# veri setini sıraya  koymak istiyorum.

df.sort_values(by = "sales", ascending = False)
# Out:
#         TV  radio  newspaper  sales
# 175  276.9   48.9       41.8   27.0
# 183  287.6   43.0       71.8   26.2
# 198  283.6   42.0       66.2   25.5
# 98   289.7   42.3       51.2   25.4
# 147  243.2   49.0       44.3   25.4
# ..     ...    ...        ...    ...
# 108   13.1    0.4       25.6    5.3
# 78     5.4   29.9        9.4    5.3
# 8      8.6    2.1        1.0    4.8
# 155    4.1   11.6        5.7    3.2
# 130    0.7   39.6        8.7    1.6
#
# [200 rows x 4 columns]

# %%
df.describe().T
# Out:
#            count      mean        std  min     25%     50%      75%    max
# TV         200.0  147.0425  85.854236  0.7  74.375  149.75  218.825  296.4
# radio      200.0   23.2640  14.846809  0.0   9.975   22.90   36.525   49.6
# newspaper  200.0   30.5540  21.778621  0.3  12.750   25.75   45.100  114.0
# sales      200.0   14.0225   5.217457  1.6  10.375   12.90   17.400   27.0

# %%
# outlier  arama 
print(np.mean([100, 110, 120, 115])) # outlier yok
print(np.std([100, 110, 120, 115]))
#ortalama 111,25 
#std = 7,3
# Out:
# 111.25
# 7.39509972887452

# %%
print(np.mean([100, 110, 120, 700])) # outlier var
print(np.std([100, 110, 120, 700]))

# std ve mean  yakınlaştı   dolayısıyla  outlier var
# Out:
# 257.5
# 255.57533136044253

# %%
print(np.mean([100, 110, 120, 900])) # outlier var
print(np.std([100, 110, 120, 900]))
# Out:
# 307.5
# 342.153109002388

# %%
sns.pairplot(df)

# %%
sns.heatmap(df.corr(), annot = True);

# %%
from scipy.stats import  skew

# %% [markdown]
# ![Ekran%20Al%C4%B1nt%C4%B1s%C4%B1.JPG](attachment:Ekran%20Al%C4%B1nt%C4%B1s%C4%B1.JPG)

# %%
# sağa ve sola çarpıklık  sorundur   biz    çan eğrissini   yakamalya çalışacağız.
# modellemde   istenen normal dağılımı  grmek istenir

# %%
for i  in  df.drop(columns = "sales").columns:
    print(i, skew(df[i]))
# Out:
# TV -0.06932836662244649
# radio 0.0934668451108453
# newspaper 0.8879959753085498

# %%
# skew   değerleri   her zaman sıfıra çekmek istiyoruz  normal değere çekip  iyi sonuçlar  almak istiyoruz.

# %%
for j in df.drop(columns = "sales").columns:
    g = sns.distplot(df[j], color = "b", label = "Skewness : %.2f"%(df[j].skew()))
    g = g.legend(loc = "best")
    plt.show()

# %%
df.corr()
# Out:
#                  TV     radio  newspaper     sales
# TV         1.000000  0.054809   0.056648  0.782224
# radio      0.054809  1.000000   0.354104  0.576223
# newspaper  0.056648  0.354104   1.000000  0.228299
# sales      0.782224  0.576223   0.228299  1.000000

# %% [markdown]
#  TV <-> sales        = 0.78 = Kuvvetli ( güçlü) doğrusal  pozitif ilişki var.
#
#  Radio <-> sales     = 0.58 = orta kuvvetli doğrusal  pozitif ilişki var.
#
#  Newspaper <-> sales = 0.23 =  <çok düşük (Zayıf) pozitif  doğrusal  ilişki var.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Train - Test Split

# %%
# !pip install scikit-learn
# !pip install sklearn (edited)
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.2.1-cp311-cp311-win_amd64.whl (8.2 MB)
#      ---------------------------------------- 8.2/8.2 MB 6.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.17.3 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.23.4)
# Requirement already satisfied: scipy>=1.3.2 in c:\users\administrator\appdata\local\programs\python\python311\lib\site-packages (from scikit-learn) (1.10.1)
# Collecting joblib>=1.1.1
#   Downloading joblib-1.2.0-py3-none-any.whl (297 kB)
#      -------------------------------------- 298.0/298.0 kB 4.6 MB/s eta 0:00:00
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Installing collected packages: threadpoolctl, joblib, scikit-learn
# Successfully installed joblib-1.2.0 scikit-learn-1.2.1 threadpoolctl-3.1.0
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ERROR: Invalid requirement: '(edited)'
#
# [notice] A new release of pip available: 22.3.1 -> 23.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# # önce   datamızın  sayısal olmalı
# # datamız  nekadar ise  1000'e kadar  ise %30 -20 test, %70 -80 train
# # datamız  100000 ise   % 10 -20 test , %90-80 train
# # datamız  100000 ile 1000000 ise  % 5 test , %95 train
# # Datamız 1000000 büyük ise  % 1 test , %99 train
# # en düşük  oran  ise % 30 test, %70 train  olabilir.Train dataların fazla olması   önemlidir

# %%
X =  df.drop(columns = "sales")
    
y = df["sales"]

print(X,y)
# Out:
#         TV  radio  newspaper
# 0    230.1   37.8       69.2
# 1     44.5   39.3       45.1
# 2     17.2   45.9       69.3
# 3    151.5   41.3       58.5
# 4    180.8   10.8       58.4
# ..     ...    ...        ...
# 195   38.2    3.7       13.8
# 196   94.2    4.9        8.1
# 197  177.0    9.3        6.4
# 198  283.6   42.0       66.2
# 199  232.1    8.6        8.7
#
# [200 rows x 3 columns] 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split
# modelimizi test ediyoruz   bu urdan sonra

# %%
X_train, X_test, y_train, Y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
df.sample(20)
# Out:
#         TV  radio  newspaper  sales
# 3    151.5   41.3       58.5   18.5
# 15   195.4   47.7       52.9   22.4
# 198  283.6   42.0       66.2   25.5
# 87   110.7   40.6       63.2   16.0
# 13    97.5    7.6        7.2    9.7
# 155    4.1   11.6        5.7    3.2
# 39   228.0   37.7       32.0   21.5
# 108   13.1    0.4       25.6    5.3
# 78     5.4   29.9        9.4    5.3
# 157  149.8    1.3       24.3   10.1
# 170   50.0   11.6       18.4    8.4
# 100  222.4    4.3       49.8   11.7
# 177  170.2    7.8       35.2   11.7
# 92   217.7   33.5       59.0   19.4
# 83    68.4   44.5       35.6   13.6
# 125   87.2   11.8       25.9   10.6
# 161   85.7   35.8       49.3   13.3
# 180  156.6    2.6        8.3   10.5
# 10    66.1    5.8       24.2    8.6
# 168  215.4   23.6       57.6   17.1

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %%
#

# %%
print("X Train features shape: {}\ny Train features shape: {}\nX Test features shape : {}\nY Test features shape : {}".format
      (X_train.shape, y_train.shape, X_test.shape, y_test.shape))
# Out:
# X Train features shape: (140, 3)
# y Train features shape: (140,)
# X Test features shape : (60, 3)
# Y Test features shape : (60,)

# %%
#Print("Train features shape: ", X_train.shape)
#Print("Train target shape: ", y_train.shape)
#Print("Test features shape: ", X_test.shape)
#Print("Test target shape: ", y_test.shape)

# %%
X_train
# Out:
#         TV  radio  newspaper
# 169  284.3   10.6        6.4
# 97   184.9   21.0       22.0
# 31   112.9   17.4       38.6
# 12    23.8   35.1       65.9
# 35   290.7    4.1        8.5
# ..     ...    ...        ...
# 106   25.0   11.0       29.7
# 14   204.1   32.9       46.0
# 92   217.7   33.5       59.0
# 179  165.6   10.0       17.6
# 102  280.2   10.1       21.4
#
# [140 rows x 3 columns]

# %%
y_train
# Out:
# 169    15.0
# 97     15.5
# 31     11.9
# 12      9.2
# 35     12.8
#        ...
# 106     7.2
# 14     19.0
# 92     19.4
# 179    12.6
# 102    14.8
# Name: sales, Length: 140, dtype: float64

# %% [markdown]
# # Model Fitting and Compare Actual and Predicted Labels

# %%
from sklearn.linear_model import LinearRegression

# %%
model =  LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
y_pred
#   model  çalıştırdık
# Out:
# array([16.5653963 , 21.18822792, 21.55107058, 10.88923816, 22.20231988,
#        13.35556872, 21.19692502,  7.35028523, 13.27547079, 15.12449511,
#         9.01443026,  6.52542825, 14.30205991,  8.97026042,  9.45679576,
#        12.00454351,  8.91549403, 16.15619251, 10.29582883, 18.72473553,
#        19.76821818, 13.77469028, 12.49638908, 21.53501762,  7.60860741,
#         5.6119801 , 20.91759483, 11.80627665,  9.08076637,  8.51412012,
#        12.17604891,  9.9691939 , 21.73008956, 12.77770578, 18.1011362 ,
#        20.07590796, 14.26202556, 20.93826535, 10.83938827,  4.38190607,
#         9.51332406, 12.40486324, 10.17045434,  8.09081363, 13.16388427,
#         5.2243552 ,  9.28893833, 14.09330719,  8.69024497, 11.66119763,
#        15.71848432, 11.63156862, 13.35360735, 11.1531472 ,  6.33636845,
#         9.76157954,  9.4195714 , 24.25516546,  7.69519137, 12.15317572])

# %%
model.coef_
# Out:
# array([0.04405928, 0.1992875 , 0.00688245])

# %%
model.intercept_
# Out:
# 2.7089490925159065

# %% [markdown]
# # y_pred = b1*TV + b2*radio +b3*newspaper + b0

# %%
sum(X_test.loc[95] * model.coef_) + model.intercept_
# manuel yapılınca böyle
# Out:
# 16.565396297434837

# %%
my_dict = {"Actual": y_test, "pred": y_pred, "residual": y_test - y_pred}

# %%
comparing = pd.DataFrame(my_dict)
comparing
# Out:
#      Actual       pred  residual
# 95     16.9  16.565396  0.334604
# 15     22.4  21.188228  1.211772
# 30     21.4  21.551071 -0.151071
# 158     7.3  10.889238 -3.589238
# 128    24.7  22.202320  2.497680
# 115    12.6  13.355569 -0.755569
# 69     22.3  21.196925  1.103075
# 170     8.4   7.350285  1.049715
# 174    11.5  13.275471 -1.775471
# 45     14.9  15.124495 -0.224495
# 66      9.5   9.014430  0.485570
# 182     8.7   6.525428  2.174572
# 165    11.9  14.302060 -2.402060
# 78      5.3   8.970260 -3.670260
# 186    10.3   9.456796  0.843204
# 177    11.7  12.004544 -0.304544
# 56      5.5   8.915494 -3.415494
# 152    16.6  16.156193  0.443807
# 82     11.3  10.295829  1.004171
# 68     18.9  18.724736  0.175264
# 124    19.7  19.768218 -0.068218
# 16     12.5  13.774690 -1.274690
# 148    10.9  12.496389 -1.596389
# 93     22.2  21.535018  0.664982
# 65      9.3   7.608607  1.691393
# 60      8.1   5.611980  2.488020
# 84     21.7  20.917595  0.782405
# 67     13.4  11.806277  1.593723
# 125    10.6   9.080766  1.519234
# 132     5.7   8.514120 -2.814120
# 9      10.6  12.176049 -1.576049
# 18     11.3   9.969194  1.330806
# 55     23.7  21.730090  1.969910
# 75      8.7  12.777706 -4.077706
# 150    16.1  18.101136 -2.001136
# 104    20.7  20.075908  0.624092
# 135    11.6  14.262026 -2.662026
# 137    20.8  20.938265 -0.138265
# 164    11.9  10.839388  1.060612
# 76      6.9   4.381906  2.518094
# 79     11.0   9.513324  1.486676
# 197    12.8  12.404863  0.395137
# 38     10.1  10.170454 -0.070454
# 24      9.7   8.090814  1.609186
# 122    11.6  13.163884 -1.563884
# 195     7.6   5.224355  2.375645
# 29     10.5   9.288938  1.211062
# 19     14.6  14.093307  0.506693
# 143    10.4   8.690245  1.709755
# 86     12.0  11.661198  0.338802
# 114    14.6  15.718484 -1.118484
# 173    11.7  11.631569  0.068431
# 5       7.2  13.353607 -6.153607
# 126     6.6  11.153147 -4.553147
# 117     9.4   6.336368  3.063632
# 73     11.0   9.761580  1.238420
# 140    10.9   9.419571  1.480429
# 98     25.4  24.255165  1.144835
# 172     7.6   7.695191 -0.095191
# 96     11.7  12.153176 -0.453176

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
result_sample = comparing.head(25)
result_sample
# Out:
#      Actual       pred  residual
# 95     16.9  16.565396  0.334604
# 15     22.4  21.188228  1.211772
# 30     21.4  21.551071 -0.151071
# 158     7.3  10.889238 -3.589238
# 128    24.7  22.202320  2.497680
# 115    12.6  13.355569 -0.755569
# 69     22.3  21.196925  1.103075
# 170     8.4   7.350285  1.049715
# 174    11.5  13.275471 -1.775471
# 45     14.9  15.124495 -0.224495
# 66      9.5   9.014430  0.485570
# 182     8.7   6.525428  2.174572
# 165    11.9  14.302060 -2.402060
# 78      5.3   8.970260 -3.670260
# 186    10.3   9.456796  0.843204
# 177    11.7  12.004544 -0.304544
# 56      5.5   8.915494 -3.415494
# 152    16.6  16.156193  0.443807
# 82     11.3  10.295829  1.004171
# 68     18.9  18.724736  0.175264
# 124    19.7  19.768218 -0.068218
# 16     12.5  13.774690 -1.274690
# 148    10.9  12.496389 -1.596389
# 93     22.2  21.535018  0.664982
# 65      9.3   7.608607  1.691393

# %%
# actual ==> sales  target
