# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats # pip install scipy
from scipy.stats import skew
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from yellowbrick.regressor import ResidualsPlot
from yellowbrick.regressor import PredictionError

plt.rcParams["figure.figsize"] = (10, 6)

import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv("co2.csv") ;df
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# 1              M6         Z                              11.2
# 2             AV7         Z                               6.0
# 3             AS6         Z                              12.7
# 4             AS6         Z                              12.1
# ...           ...       ...                               ...
# 7380          AS8         Z                              10.7
# 7381          AS8         Z                              11.2
# 7382          AS8         Z                              11.7
# 7383          AS8         Z                              11.2
# 7384          AS8         Z                              12.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 0                                 6.7                               8.5
# 1                                 7.7                               9.6
# 2                                 5.8                               5.9
# 3                                 9.1                              11.1
# 4                                 8.7                              10.6
# ...                               ...                               ...
# 7380                              7.7                               9.4
# 7381                              8.3                               9.9
# 7382                              8.6                              10.3
# 7383                              8.3                               9.9
# 7384                              8.7                              10.7
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 0                              33                  196
# 1                              29                  221
# 2                              48                  136
# 3                              25                  255
# 4                              27                  244
# ...                           ...                  ...
# 7380                           30                  219
# 7381                           29                  232
# 7382                           27                  240
# 7383                           29                  232
# 7384                           26                  248
#
# [7385 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7385 entries, 0 to 7384
# Data columns (total 12 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Make                              7385 non-null   object
#  1   Model                             7385 non-null   object
#  2   Vehicle Class                     7385 non-null   object
#  3   Engine Size(L)                    7385 non-null   float64
#  4   Cylinders                         7385 non-null   int64
#  5   Transmission                      7385 non-null   object
#  6   Fuel Type                         7385 non-null   object
#  7   Fuel Consumption City (L/100 km)  7385 non-null   float64
#  8   Fuel Consumption Hwy (L/100 km)   7385 non-null   float64
#  9   Fuel Consumption Comb (L/100 km)  7385 non-null   float64
#  10  Fuel Consumption Comb (mpg)       7385 non-null   int64
#  11  CO2 Emissions(g/km)               7385 non-null   int64
# dtypes: float64(4), int64(3), object(5)
# memory usage: 692.5+ KB

# %%
df.sort_values(by = "CO2 Emissions(g/km)", ascending = False)
# Out:
#              Make               Model Vehicle Class  Engine Size(L)  \
# 5575      BUGATTI              Chiron    TWO-SEATER             8.0
# 6640      BUGATTI              Chiron    TWO-SEATER             8.0
# 4509      BUGATTI              CHIRON    TWO-SEATER             8.0
# 7059  LAMBORGHINI  Aventador Roadster    TWO-SEATER             6.5
# 6046  LAMBORGHINI  Aventador Roadster    TWO-SEATER             6.5
# ...           ...                 ...           ...             ...
# 6949      HYUNDAI               IONIQ     FULL-SIZE             1.6
# 5931      HYUNDAI          IONIQ Blue     FULL-SIZE             1.6
# 4900      HYUNDAI          IONIQ BLUE     FULL-SIZE             1.6
# 6950      HYUNDAI          IONIQ Blue     FULL-SIZE             1.6
# 3824      HYUNDAI          IONIQ BLUE     FULL-SIZE             1.6
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 5575         16          AM7         Z                              26.8
# 6640         16          AM7         Z                              26.8
# 4509         16          AM7         Z                              26.8
# 7059         12          AM7         Z                              26.6
# 6046         12          AM7         Z                              26.6
# ...         ...          ...       ...                               ...
# 6949          4          AM6         X                               4.2
# 5931          4          AM6         X                               4.2
# 4900          4          AM6         X                               4.2
# 6950          4          AM6         X                               4.2
# 3824          4          AM6         X                               4.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 5575                             16.6                              22.2
# 6640                             16.6                              22.2
# 4509                             16.6                              22.2
# 7059                             15.8                              21.7
# 6046                             15.8                              21.7
# ...                               ...                               ...
# 6949                              4.2                               4.2
# 5931                              4.0                               4.1
# 4900                              4.0                               4.1
# 6950                              4.0                               4.1
# 3824                              4.0                               4.1
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 5575                           13                  522
# 6640                           13                  522
# 4509                           13                  522
# 7059                           13                  493
# 6046                           13                  493
# ...                           ...                  ...
# 6949                           67                   99
# 5931                           69                   96
# 4900                           69                   96
# 6950                           69                   96
# 3824                           69                   96
#
# [7385 rows x 12 columns]

# %%
df.describe().T
# Out:
#                                    count        mean        std   min    25%  \
# Engine Size(L)                    7385.0    3.160068   1.354170   0.9    2.0
# Cylinders                         7385.0    5.615030   1.828307   3.0    4.0
# Fuel Consumption City (L/100 km)  7385.0   12.556534   3.500274   4.2   10.1
# Fuel Consumption Hwy (L/100 km)   7385.0    9.041706   2.224456   4.0    7.5
# Fuel Consumption Comb (L/100 km)  7385.0   10.975071   2.892506   4.1    8.9
# Fuel Consumption Comb (mpg)       7385.0   27.481652   7.231879  11.0   22.0
# CO2 Emissions(g/km)               7385.0  250.584699  58.512679  96.0  208.0
#
#                                     50%    75%    max
# Engine Size(L)                      3.0    3.7    8.4
# Cylinders                           6.0    6.0   16.0
# Fuel Consumption City (L/100 km)   12.1   14.6   30.6
# Fuel Consumption Hwy (L/100 km)     8.7   10.2   20.6
# Fuel Consumption Comb (L/100 km)   10.6   12.6   26.1
# Fuel Consumption Comb (mpg)        27.0   32.0   69.0
# CO2 Emissions(g/km)               246.0  288.0  522.0

# %%
sns.pairplot(df);

# %%
sns.heatmap(df.corr(), annot = True);

# %%
for i in df.drop(columns = ["Make","Model","Vehicle Class","Transmission","Fuel Type","CO2 Emissions(g/km)"]).columns:
    print(i, skew(df[i]))
# Out:
# Engine Size(L) 0.8090166237091084
# Cylinders 1.1101898640440213
# Fuel Consumption City (L/100 km) 0.8088403827811873
# Fuel Consumption Hwy (L/100 km) 1.078997475325438
# Fuel Consumption Comb (L/100 km) 0.8931342662031229
# Fuel Consumption Comb (mpg) 0.9768356000735062

# %%
for j in df.drop(columns = ["Make","Model","Vehicle Class","Transmission","Fuel Type","CO2 Emissions(g/km)"]).columns:
    g = sns.distplot(df[j], color = "b", label = "Skewness : %.2f"%(df[j].skew()))
    g = g.legend(loc = "best")
    plt.show()

# %%
df2 = df.drop_duplicates(subset=["Make", "Model"]); df2
# Out:
#             Make                                   Model  \
# 0          ACURA                                     ILX
# 2          ACURA                              ILX HYBRID
# 3          ACURA                                 MDX 4WD
# 4          ACURA                                 RDX AWD
# 5          ACURA                                     RLX
# ...          ...                                     ...
# 7340      TOYOTA  Highlander Hybrid AWD Limited/Platinum
# 7346      TOYOTA                   RAV4 AWD TRD Off-Road
# 7355      TOYOTA       Tacoma 4WD D-Cab TRD Off-Road/Pro
# 7361  VOLKSWAGEN               Atlas Cross Sport 4MOTION
# 7379       VOLVO                             XC40 T4 AWD
#
#              Vehicle Class  Engine Size(L)  Cylinders Transmission Fuel Type  \
# 0                  COMPACT             2.0          4          AS5         Z
# 2                  COMPACT             1.5          4          AV7         Z
# 3              SUV - SMALL             3.5          6          AS6         Z
# 4              SUV - SMALL             3.5          6          AS6         Z
# 5                 MID-SIZE             3.5          6          AS6         Z
# ...                    ...             ...        ...          ...       ...
# 7340        SUV - STANDARD             2.5          4           AV         X
# 7346           SUV - SMALL             2.5          4          AS8         X
# 7355  PICKUP TRUCK - SMALL             3.5          6           M6         X
# 7361           SUV - SMALL             2.0          4          AS8         X
# 7379           SUV - SMALL             2.0          4          AS8         X
#
#       Fuel Consumption City (L/100 km)  Fuel Consumption Hwy (L/100 km)  \
# 0                                  9.9                              6.7
# 2                                  6.0                              5.8
# 3                                 12.7                              9.1
# 4                                 12.1                              8.7
# 5                                 11.9                              7.7
# ...                                ...                              ...
# 7340                               6.6                              6.8
# 7346                               9.5                              7.5
# 7355                              13.8                             11.7
# 7361                              12.8                             10.4
# 7379                              10.2                              7.5
#
#       Fuel Consumption Comb (L/100 km)  Fuel Consumption Comb (mpg)  \
# 0                                  8.5                           33
# 2                                  5.9                           48
# 3                                 11.1                           25
# 4                                 10.6                           27
# 5                                 10.0                           28
# ...                                ...                          ...
# 7340                               6.7                           42
# 7346                               8.6                           33
# 7355                              12.9                           22
# 7361                              11.7                           24
# 7379                               9.0                           31
#
#       CO2 Emissions(g/km)
# 0                     196
# 2                     136
# 3                     255
# 4                     244
# 5                     230
# ...                   ...
# 7340                  156
# 7346                  200
# 7355                  300
# 7361                  273
# 7379                  210
#
# [2053 rows x 12 columns]

# %%
df2.sort_values(by = "CO2 Emissions(g/km)", ascending = False)
# Out:
#              Make               Model    Vehicle Class  Engine Size(L)  \
# 4509      BUGATTI              CHIRON       TWO-SEATER             8.0
# 5575      BUGATTI              Chiron       TWO-SEATER             8.0
# 6046  LAMBORGHINI  Aventador Roadster       TWO-SEATER             6.5
# 349          FORD          E350 WAGON  VAN - PASSENGER             6.8
# 6045  LAMBORGHINI     Aventador Coupe       TWO-SEATER             6.5
# ...           ...                 ...              ...             ...
# 7335       TOYOTA      Corolla Hybrid          COMPACT             1.8
# 6442       TOYOTA               Prius         MID-SIZE             1.8
# 3823      HYUNDAI               IONIQ        FULL-SIZE             1.6
# 5931      HYUNDAI          IONIQ Blue        FULL-SIZE             1.6
# 3824      HYUNDAI          IONIQ BLUE        FULL-SIZE             1.6
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 4509         16          AM7         Z                              26.8
# 5575         16          AM7         Z                              26.8
# 6046         12          AM7         Z                              26.6
# 349          10           A5         X                              23.9
# 6045         12          AM7         Z                              26.3
# ...         ...          ...       ...                               ...
# 7335          4           AV         X                               4.4
# 6442          4           AV         X                               4.4
# 3823          4          AM6         X                               4.3
# 5931          4          AM6         X                               4.2
# 3824          4          AM6         X                               4.2
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 4509                             16.6                              22.2
# 5575                             16.6                              22.2
# 6046                             15.8                              21.7
# 349                              17.8                              21.2
# 6045                             15.6                              21.5
# ...                               ...                               ...
# 7335                              4.5                               4.5
# 6442                              4.6                               4.4
# 3823                              4.4                               4.4
# 5931                              4.0                               4.1
# 3824                              4.0                               4.1
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 4509                           13                  522
# 5575                           13                  522
# 6046                           13                  493
# 349                            13                  488
# 6045                           13                  487
# ...                           ...                  ...
# 7335                           63                  106
# 6442                           64                  105
# 3823                           64                  103
# 5931                           69                   96
# 3824                           69                   96
#
# [2053 rows x 12 columns]

# %%
df3 = df2.drop_duplicates(subset=["Make", "Engine Size(L)","Cylinders","Fuel Consumption City (L/100 km)"]); df3
# Out:
#             Make                                   Model   Vehicle Class  \
# 0          ACURA                                     ILX         COMPACT
# 2          ACURA                              ILX HYBRID         COMPACT
# 3          ACURA                                 MDX 4WD     SUV - SMALL
# 4          ACURA                                 RDX AWD     SUV - SMALL
# 5          ACURA                                     RLX        MID-SIZE
# ...          ...                                     ...             ...
# 7331      TOYOTA                             Corolla XSE         COMPACT
# 7336      TOYOTA                                GR Supra      TWO-SEATER
# 7340      TOYOTA  Highlander Hybrid AWD Limited/Platinum  SUV - STANDARD
# 7361  VOLKSWAGEN               Atlas Cross Sport 4MOTION     SUV - SMALL
# 7379       VOLVO                             XC40 T4 AWD     SUV - SMALL
#
#       Engine Size(L)  Cylinders Transmission Fuel Type  \
# 0                2.0          4          AS5         Z
# 2                1.5          4          AV7         Z
# 3                3.5          6          AS6         Z
# 4                3.5          6          AS6         Z
# 5                3.5          6          AS6         Z
# ...              ...        ...          ...       ...
# 7331             2.0          4         AV10         X
# 7336             3.0          6          AS8         Z
# 7340             2.5          4           AV         X
# 7361             2.0          4          AS8         X
# 7379             2.0          4          AS8         X
#
#       Fuel Consumption City (L/100 km)  Fuel Consumption Hwy (L/100 km)  \
# 0                                  9.9                              6.7
# 2                                  6.0                              5.8
# 3                                 12.7                              9.1
# 4                                 12.1                              8.7
# 5                                 11.9                              7.7
# ...                                ...                              ...
# 7331                               7.7                              6.1
# 7336                               9.9                              7.7
# 7340                               6.6                              6.8
# 7361                              12.8                             10.4
# 7379                              10.2                              7.5
#
#       Fuel Consumption Comb (L/100 km)  Fuel Consumption Comb (mpg)  \
# 0                                  8.5                           33
# 2                                  5.9                           48
# 3                                 11.1                           25
# 4                                 10.6                           27
# 5                                 10.0                           28
# ...                                ...                          ...
# 7331                               7.0                           40
# 7336                               8.9                           32
# 7340                               6.7                           42
# 7361                              11.7                           24
# 7379                               9.0                           31
#
#       CO2 Emissions(g/km)
# 0                     196
# 2                     136
# 3                     255
# 4                     244
# 5                     230
# ...                   ...
# 7331                  164
# 7336                  208
# 7340                  156
# 7361                  273
# 7379                  210
#
# [1328 rows x 12 columns]

# %%
df3.sort_values(by = "CO2 Emissions(g/km)", ascending = False).head(50)
# Out:
#                Make                         Model             Vehicle Class  \
# 4509        BUGATTI                        CHIRON                TWO-SEATER
# 6046    LAMBORGHINI            Aventador Roadster                TWO-SEATER
# 349            FORD                    E350 WAGON           VAN - PASSENGER
# 6045    LAMBORGHINI               Aventador Coupe                TWO-SEATER
# 2971  MERCEDES-BENZ                      AMG G 65            SUV - STANDARD
# 5511        BENTLEY                      Mulsanne                  MID-SIZE
# 5028    LAMBORGHINI          AVENTADOR S ROADSTER                TWO-SEATER
# 3959    LAMBORGHINI        AVENTADOR COUPE LP 740                TWO-SEATER
# 5027    LAMBORGHINI             AVENTADOR S COUPE                TWO-SEATER
# 1743    LAMBORGHINI            AVENTADOR ROADSTER                TWO-SEATER
# 1328      CHEVROLET    EXPRESS 3500 PASSENGER FFV           VAN - PASSENGER
# 75          BENTLEY                      MULSANNE                  MID-SIZE
# 1533            GMC     SAVANA 3500 PASSENGER FFV           VAN - PASSENGER
# 1529            GMC     SAVANA 2500 PASSENGER FFV           VAN - PASSENGER
# 1324      CHEVROLET    EXPRESS 2500 PASSENGER FFV           VAN - PASSENGER
# 3376        BENTLEY                  MULSANNE EWB                  MID-SIZE
# 1745    LAMBORGHINI               VENENO ROADSTER                TWO-SEATER
# 350            FORD                E350 WAGON FFV           VAN - PASSENGER
# 637     LAMBORGHINI               AVENTADOR COUPE                TWO-SEATER
# 758   MERCEDES-BENZ                         G 550            SUV - STANDARD
# 450             GMC         SAVANA 3500 PASSENGER           VAN - PASSENGER
# 226       CHEVROLET        EXPRESS 3500 PASSENGER           VAN - PASSENGER
# 447             GMC         SAVANA 2500 PASSENGER           VAN - PASSENGER
# 223       CHEVROLET        EXPRESS 2500 PASSENGER           VAN - PASSENGER
# 391            FORD              F-150 RAPTOR 4X4   PICKUP TRUCK - STANDARD
# 4975           JEEP  GRAND CHEROKEE 4X4 TRACKHAWK            SUV - STANDARD
# 759   MERCEDES-BENZ                      G 63 AMG            SUV - STANDARD
# 3703           FORD                            GT                TWO-SEATER
# 864          NISSAN                     TITAN 4WD   PICKUP TRUCK - STANDARD
# 6395    ROLLS-ROYCE                          Dawn                   COMPACT
# 929     ROLLS-ROYCE                       PHANTOM                 FULL-SIZE
# 6832           FORD          Shelby GT500 Mustang                SUBCOMPACT
# 4247    ROLLS-ROYCE                          DAWN                   COMPACT
# 945             SRT                   VIPER COUPE                TWO-SEATER
# 4436        BENTLEY       CONTINENTAL SUPERSPORTS                   COMPACT
# 74          BENTLEY                   FLYING SPUR                  MID-SIZE
# 6400    ROLLS-ROYCE                        Wraith                  MID-SIZE
# 3616          DODGE                         VIPER                TWO-SEATER
# 347            FORD                E150 WAGON FFV           VAN - PASSENGER
# 7286    ROLLS-ROYCE          Cullinan Black Badge  STATION WAGON - MID-SIZE
# 6053    LAMBORGHINI                          Urus            SUV - STANDARD
# 6448         TOYOTA                   Sequoia 4WD            SUV - STANDARD
# 998          TOYOTA                   SEQUOIA 4WD            SUV - STANDARD
# 173        CADILLAC                   CTS-V COUPE                  MID-SIZE
# 193       CHEVROLET                    CAMARO ZL1                   COMPACT
# 6394    ROLLS-ROYCE                      Cullinan  STATION WAGON - MID-SIZE
# 6391            RAM              1500 Classic 4X4   PICKUP TRUCK - STANDARD
# 5631      CHEVROLET                  Corvette ZR1                TWO-SEATER
# 215       CHEVROLET       EXPRESS 1500 CARGO CONV               VAN - CARGO
# 439             GMC        SAVANA 1500 CARGO CONV               VAN - CARGO
#
#       Engine Size(L)  Cylinders Transmission Fuel Type  \
# 4509             8.0         16          AM7         Z
# 6046             6.5         12          AM7         Z
# 349              6.8         10           A5         X
# 6045             6.5         12          AM7         Z
# 2971             6.0         12          AS7         Z
# 5511             6.8          8          AS8         Z
# 5028             6.5         12          AM7         Z
# 3959             6.5         12          AM7         Z
# 5027             6.5         12          AM7         Z
# 1743             6.5         12          AM7         Z
# 1328             6.0          8           A6         X
# 75               6.8          8          AS8         Z
# 1533             6.0          8           A6         X
# 1529             6.0          8           A6         X
# 1324             6.0          8           A6         X
# 3376             6.8          8          AS8         Z
# 1745             6.5         12          AM7         Z
# 350              5.4          8           A4         X
# 637              6.5         12           A7         Z
# 758              5.5          8          AS7         Z
# 450              4.8          8           A6         X
# 226              4.8          8           A6         X
# 447              4.8          8           A6         X
# 223              4.8          8           A6         X
# 391              6.2          8          AS6         X
# 4975             6.2          8           A8         Z
# 759              5.5          8          AS7         Z
# 3703             3.5          6          AM7         Z
# 864              5.6          8           A5         X
# 6395             6.6         12          AS8         Z
# 929              6.7         12           A8         Z
# 6832             5.2          8          AM7         Z
# 4247             6.6         12          AS8         Z
# 945              8.4         10           M6         Z
# 4436             6.0         12          AS8         Z
# 74               6.0         12          AS8         Z
# 6400             6.6         12          AS8         Z
# 3616             8.4         10           M6         Z
# 347              4.6          8           A4         X
# 7286             6.7         12          AS8         Z
# 6053             4.0          8          AS8         Z
# 6448             5.7          8          AS6         X
# 998              5.7          8          AS6         X
# 173              6.2          8          AS6         Z
# 193              6.2          8          AS6         Z
# 6394             6.7         12          AS8         Z
# 6391             5.7          8           A6         X
# 5631             6.2          8          AS8         Z
# 215              5.3          8           A4         X
# 439              5.3          8           A4         X
#
#       Fuel Consumption City (L/100 km)  Fuel Consumption Hwy (L/100 km)  \
# 4509                              26.8                             16.6
# 6046                              26.6                             15.8
# 349                               23.9                             17.8
# 6045                              26.3                             15.6
# 2971                              24.3                             17.9
# 5511                              24.5                             14.4
# 5028                              24.2                             14.5
# 3959                              23.9                             14.5
# 5027                              23.8                             14.1
# 1743                              24.0                             14.5
# 1328                              22.2                             15.1
# 75                                22.3                             14.9
# 1533                              22.2                             15.1
# 1529                              22.0                             14.9
# 1324                              22.0                             14.9
# 3376                              22.2                             13.6
# 1745                              22.1                             13.9
# 350                               20.6                             15.5
# 637                               22.8                             12.9
# 758                               20.0                             15.9
# 450                               21.3                             14.3
# 226                               21.3                             14.3
# 447                               21.1                             14.2
# 223                               21.1                             14.2
# 391                               20.4                             15.0
# 4975                              20.9                             13.8
# 759                               19.4                             15.7
# 3703                              20.6                             13.2
# 864                               19.7                             14.3
# 6395                              20.3                             13.0
# 929                               20.7                             12.8
# 6832                              19.9                             12.7
# 4247                              20.0                             12.6
# 945                               20.0                             13.0
# 4436                              20.4                             12.0
# 74                                20.3                             11.9
# 6400                              19.6                             12.9
# 3616                              19.9                             12.6
# 347                               18.6                             14.6
# 7286                              20.1                             12.1
# 6053                              19.2                             14.1
# 6448                              18.4                             13.8
# 998                               19.0                             13.9
# 173                               19.7                             12.9
# 193                               19.7                             12.9
# 6394                              20.0                             11.8
# 6391                              18.7                             13.3
# 5631                              19.5                             12.0
# 215                               18.6                             13.9
# 439                               18.6                             13.9
#
#       Fuel Consumption Comb (L/100 km)  Fuel Consumption Comb (mpg)  \
# 4509                              22.2                           13
# 6046                              21.7                           13
# 349                               21.2                           13
# 6045                              21.5                           13
# 2971                              21.4                           13
# 5511                              20.0                           14
# 5028                              19.8                           14
# 3959                              19.7                           14
# 5027                              19.4                           15
# 1743                              19.7                           14
# 1328                              19.0                           15
# 75                                19.0                           15
# 1533                              19.0                           15
# 1529                              18.8                           15
# 1324                              18.8                           15
# 3376                              18.3                           15
# 1745                              18.4                           15
# 350                               18.3                           15
# 637                               18.3                           15
# 758                               18.2                           16
# 450                               18.2                           16
# 226                               18.2                           16
# 447                               18.0                           16
# 223                               18.0                           16
# 391                               18.0                           16
# 4975                              17.7                           16
# 759                               17.7                           16
# 3703                              17.3                           16
# 864                               17.3                           16
# 6395                              17.0                           17
# 929                               17.1                           17
# 6832                              16.7                           17
# 4247                              16.7                           17
# 945                               16.9                           17
# 4436                              16.6                           17
# 74                                16.5                           17
# 6400                              16.6                           17
# 3616                              16.6                           17
# 347                               16.8                           17
# 7286                              16.5                           17
# 6053                              16.9                           17
# 6448                              16.4                           17
# 998                               16.7                           17
# 173                               16.6                           17
# 193                               16.6                           17
# 6394                              16.3                           17
# 6391                              16.3                           17
# 5631                              16.1                           18
# 215                               16.5                           17
# 439                               16.5                           17
#
#       CO2 Emissions(g/km)
# 4509                  522
# 6046                  493
# 349                   488
# 6045                  487
# 2971                  476
# 5511                  465
# 5028                  464
# 3959                  461
# 5027                  454
# 1743                  453
# 1328                  437
# 75                    437
# 1533                  437
# 1529                  432
# 1324                  432
# 3376                  430
# 1745                  423
# 350                   421
# 637                   421
# 758                   419
# 450                   419
# 226                   419
# 447                   414
# 223                   414
# 391                   414
# 4975                  413
# 759                   407
# 3703                  406
# 864                   398
# 6395                  397
# 929                   393
# 6832                  392
# 4247                  390
# 945                   389
# 4436                  389
# 74                    388
# 6400                  388
# 3616                  387
# 347                   386
# 7286                  386
# 6053                  384
# 6448                  384
# 998                   384
# 173                   382
# 193                   382
# 6394                  382
# 6391                  382
# 5631                  381
# 215                   380
# 439                   380

# %%
df3.describe().T
# Out:
#                                    count        mean        std   min    25%  \
# Engine Size(L)                    1328.0    3.219352   1.399691   1.0    2.0
# Cylinders                         1328.0    5.737199   1.946009   3.0    4.0
# Fuel Consumption City (L/100 km)  1328.0   12.476130   3.461836   4.2   10.1
# Fuel Consumption Hwy (L/100 km)   1328.0    9.031250   2.092732   4.0    7.6
# Fuel Consumption Comb (L/100 km)  1328.0   10.924925   2.806423   4.1    9.0
# Fuel Consumption Comb (mpg)       1328.0   27.655120   7.658107  13.0   22.0
# CO2 Emissions(g/km)               1328.0  254.731928  64.539704  96.0  209.0
#
#                                     50%    75%    max
# Engine Size(L)                      3.0    3.8    8.4
# Cylinders                           6.0    6.0   16.0
# Fuel Consumption City (L/100 km)   12.1   14.5   26.8
# Fuel Consumption Hwy (L/100 km)     8.8   10.2   17.9
# Fuel Consumption Comb (L/100 km)   10.6   12.6   22.2
# Fuel Consumption Comb (mpg)        27.0   31.0   69.0
# CO2 Emissions(g/km)               249.0  293.0  522.0

# %%
df3.sort_values(by = "Cylinders", ascending = False)
# Out:
#                Make                Model   Vehicle Class  Engine Size(L)  \
# 4509        BUGATTI               CHIRON      TWO-SEATER             8.0
# 2971  MERCEDES-BENZ             AMG G 65  SUV - STANDARD             6.0
# 1875  MERCEDES-BENZ             S 65 AMG       FULL-SIZE             6.0
# 74          BENTLEY          FLYING SPUR        MID-SIZE             6.0
# 5477   ASTON MARTIN           Rapide AMR      SUBCOMPACT             6.0
# ...             ...                  ...             ...             ...
# 4107           MINI  COOPER CLUBMAN ALL4        MID-SIZE             1.5
# 1886           MINI        COOPER 3 DOOR      SUBCOMPACT             1.5
# 6645          BUICK            Encore GX     SUV - SMALL             1.2
# 6646          BUICK        Encore GX AWD     SUV - SMALL             1.3
# 3687           FORD   FOCUS (Start/Stop)         COMPACT             1.0
#
#       Cylinders Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 4509         16          AM7         Z                              26.8
# 2971         12          AS7         Z                              24.3
# 1875         12          AS7         Z                              18.5
# 74           12          AS8         Z                              20.3
# 5477         12           A8         Z                              16.7
# ...         ...          ...       ...                               ...
# 4107          3          AS8         Z                              10.2
# 1886          3          AS6         Z                               8.5
# 6645          3           AV         X                               9.0
# 6646          3           A9         X                               9.0
# 3687          3          AS6         X                               8.5
#
#       Fuel Consumption Hwy (L/100 km)  Fuel Consumption Comb (L/100 km)  \
# 4509                             16.6                              22.2
# 2971                             17.9                              21.4
# 1875                             11.8                              15.5
# 74                               11.9                              16.5
# 5477                             10.9                              14.1
# ...                               ...                               ...
# 4107                              7.8                               9.1
# 1886                              6.3                               7.5
# 6645                              7.7                               8.4
# 6646                              8.0                               8.5
# 3687                              6.2                               7.5
#
#       Fuel Consumption Comb (mpg)  CO2 Emissions(g/km)
# 4509                           13                  522
# 2971                           13                  476
# 1875                           18                  357
# 74                             17                  388
# 5477                           20                  332
# ...                           ...                  ...
# 4107                           31                  213
# 1886                           38                  172
# 6645                           34                  198
# 6646                           33                  199
# 3687                           38                  176
#
# [1328 rows x 12 columns]

# %%
sns.pairplot(df3);

# %%
sns.heatmap(df3.corr(), annot = True);

# %%
for i in df3.drop(columns = ["Make","Model","Vehicle Class","Transmission","Fuel Type","CO2 Emissions(g/km)"]).columns:
    print(i, skew(df[i]))
# Out:
# Engine Size(L) 0.8090166237091084
# Cylinders 1.1101898640440213
# Fuel Consumption City (L/100 km) 0.8088403827811873
# Fuel Consumption Hwy (L/100 km) 1.078997475325438
# Fuel Consumption Comb (L/100 km) 0.8931342662031229
# Fuel Consumption Comb (mpg) 0.9768356000735062

# %%
df3.corr()
# Out:
#                                   Engine Size(L)  Cylinders  \
# Engine Size(L)                          1.000000   0.919119
# Cylinders                               0.919119   1.000000
# Fuel Consumption City (L/100 km)        0.852149   0.829064
# Fuel Consumption Hwy (L/100 km)         0.787157   0.747868
# Fuel Consumption Comb (L/100 km)        0.841837   0.812785
# Fuel Consumption Comb (mpg)            -0.729441  -0.696420
# CO2 Emissions(g/km)                     0.840425   0.815714
#
#                                   Fuel Consumption City (L/100 km)  \
# Engine Size(L)                                            0.852149
# Cylinders                                                 0.829064
# Fuel Consumption City (L/100 km)                          1.000000
# Fuel Consumption Hwy (L/100 km)                           0.938823
# Fuel Consumption Comb (L/100 km)                          0.993214
# Fuel Consumption Comb (mpg)                              -0.921936
# CO2 Emissions(g/km)                                       0.988151
#
#                                   Fuel Consumption Hwy (L/100 km)  \
# Engine Size(L)                                           0.787157
# Cylinders                                                0.747868
# Fuel Consumption City (L/100 km)                         0.938823
# Fuel Consumption Hwy (L/100 km)                          1.000000
# Fuel Consumption Comb (L/100 km)                         0.972176
# Fuel Consumption Comb (mpg)                             -0.891165
# CO2 Emissions(g/km)                                      0.967011
#
#                                   Fuel Consumption Comb (L/100 km)  \
# Engine Size(L)                                            0.841837
# Cylinders                                                 0.812785
# Fuel Consumption City (L/100 km)                          0.993214
# Fuel Consumption Hwy (L/100 km)                           0.972176
# Fuel Consumption Comb (L/100 km)                          1.000000
# Fuel Consumption Comb (mpg)                              -0.924380
# CO2 Emissions(g/km)                                       0.994682
#
#                                   Fuel Consumption Comb (mpg)  \
# Engine Size(L)                                      -0.729441
# Cylinders                                           -0.696420
# Fuel Consumption City (L/100 km)                    -0.921936
# Fuel Consumption Hwy (L/100 km)                     -0.891165
# Fuel Consumption Comb (L/100 km)                    -0.924380
# Fuel Consumption Comb (mpg)                          1.000000
# CO2 Emissions(g/km)                                 -0.921520
#
#                                   CO2 Emissions(g/km)
# Engine Size(L)                               0.840425
# Cylinders                                    0.815714
# Fuel Consumption City (L/100 km)             0.988151
# Fuel Consumption Hwy (L/100 km)              0.967011
# Fuel Consumption Comb (L/100 km)             0.994682
# Fuel Consumption Comb (mpg)                 -0.921520
# CO2 Emissions(g/km)                          1.000000

# %%
X=df3[['Engine Size(L)','Fuel Consumption Comb (L/100 km)','Cylinders']]

y=df3['CO2 Emissions(g/km)']

print(X, y)
# Out:
#       Engine Size(L)  Fuel Consumption Comb (L/100 km)  Cylinders
# 0                2.0                               8.5          4
# 2                1.5                               5.9          4
# 3                3.5                              11.1          6
# 4                3.5                              10.6          6
# 5                3.5                              10.0          6
# ...              ...                               ...        ...
# 7331             2.0                               7.0          4
# 7336             3.0                               8.9          6
# 7340             2.5                               6.7          4
# 7361             2.0                              11.7          4
# 7379             2.0                               9.0          4
#
# [1328 rows x 3 columns] 0       196
# 2       136
# 3       255
# 4       244
# 5       230
#        ...
# 7331    164
# 7336    208
# 7340    156
# 7361    273
# 7379    210
# Name: CO2 Emissions(g/km), Length: 1328, dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.14, random_state = 44)

# %%
print("X Train features shape: {}\ny Train features shape: {}\nX Test features shape : {}\ny Test features shape : {}".format
      (X_train.shape, y_train.shape, X_test.shape, y_test.shape))
# Out:
# X Train features shape: (1142, 3)
# y Train features shape: (1142,)
# X Test features shape : (186, 3)
# y Test features shape : (186,)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([378.59877874, 227.97994043, 266.02491176, 207.975456  ,
#        218.91867461, 223.35346661, 256.38860045, 198.91419018,
#        288.10303081, 158.61769858, 285.83771436, 223.83267118,
#        311.2143306 , 221.56735473, 238.36190973, 267.61934181,
#        236.57579785, 228.36330409, 420.04536132, 340.30115017,
#        180.79165855, 237.42456991, 265.44986627, 179.46368192,
#        220.71858267, 301.38633746, 214.77140536, 203.44482309,
#        146.39116228, 219.87708376, 243.74131469, 224.96169284,
#        198.91419018, 237.42456991, 340.08839902, 272.34165655,
#        194.95860277, 286.41275985, 299.23793125, 212.50608891,
#        230.62862054, 267.81102364, 214.3880417 , 292.63366372,
#        261.59011977, 248.2719476 , 189.85292437, 265.31663956,
#        263.28039073, 187.10840334, 296.12384274, 294.70729834,
#        226.09798764, 457.81660609, 247.90238012, 271.30120266,
#        269.70677261, 218.45326622, 218.45326622, 274.51113208,
#        191.63903625, 252.43301303, 212.50608891, 285.83771436,
#        333.70340568, 503.12293517, 332.17722418, 223.83267118,
#        365.51367695, 300.84615748, 158.13849401, 232.04516494,
#        270.26802192, 218.91867461, 308.94901415, 238.84111431,
#        313.7671698 , 189.46956071, 206.09350321, 205.71013955,
#        209.76156788, 258.55807599, 169.94428086, 347.95239463,
#        385.87393268, 192.11824082, 205.71013955, 259.40684804,
#        312.36442158, 260.72755153, 133.22001301, 286.70028259,
#        312.55610341, 222.60053547, 231.10782512, 212.50608891,
#        295.93216091, 237.13704716, 389.1934992 , 240.62722619,
#        227.97994043, 189.37371979, 290.94339276, 214.06313316,
#        222.50469455, 308.85317323, 236.57579785, 168.9858717 ,
#        385.80568413, 196.64887373, 198.91419018, 137.27144134,
#        408.71877905, 254.21912491, 232.51057334, 276.50272198,
#        274.51113208, 183.6320205 , 162.66912692, 256.96364594,
#        216.18794976, 142.28127883, 241.57183916, 231.29950695,
#        122.08511257, 324.07436752, 192.30992265, 310.66035444,
#        383.12941165, 308.21715234, 304.05608691, 185.89733695,
#        348.03443936, 212.50608891, 261.86384633, 341.81353549,
#        232.893937  , 408.04789264, 349.56062086, 276.77644854,
#        309.52405964, 320.56311916, 281.30708145, 252.43301303,
#        173.99570919, 153.6078611 , 373.90405637, 222.27562693,
#        371.80282938, 201.17950664, 245.06201818, 281.30708145,
#        272.53333838, 244.87033635, 335.55776611, 178.04713752,
#        233.83127682, 199.48923568, 196.64887373, 256.96364594,
#        284.51701087, 274.23740552, 189.85292437, 307.25874318,
#        158.61769858, 250.16769658, 225.24921558, 236.7536835 ,
#        193.9043527 , 198.91419018, 238.84111431, 241.95520282,
#        219.30203827, 437.68868838, 328.9745679 , 121.41422616,
#        276.10556213, 225.61878306, 212.98529349, 496.80619039,
#        212.12272525, 223.83267118, 288.19887173, 194.76692094,
#        355.98047971, 217.03672182])

# %%
model.coef_
# Out:
# array([-0.95840915, 22.65316454,  1.18747678])

# %%
X_test.head()
# Out:
#       Engine Size(L)  Fuel Consumption Comb (L/100 km)  Cylinders
# 181              6.2                              16.4          8
# 293              2.4                               9.8          4
# 6353             3.0                              11.4          6
# 1095             2.0                               8.9          4
# 1573             2.4                               9.4          4

# %%
model.intercept_
# Out:
# 3.529202771303318

# %%
my_dict = {"Actual": y_test, "pred": y_pred, "residual": y_test - y_pred}

# %%
comparing = pd.DataFrame(my_dict)
comparing
# Out:
#       Actual        pred  residual
# 181      377  378.598779 -1.598779
# 293      225  227.979940 -2.979940
# 6353     265  266.024912 -1.024912
# 1095     205  207.975456 -2.975456
# 1573     216  218.918675 -2.918675
# ...      ...         ...       ...
# 1776     221  223.832671 -2.832671
# 1000     285  288.198872 -3.198872
# 796      191  194.766921 -3.766921
# 6116     360  355.980480  4.019520
# 854      214  217.036722 -3.036722
#
# [186 rows x 3 columns]

# %%
sum(X_test.loc[181] * model.coef_) + model.intercept_#manual
# Out:
# 378.5987787385028

# %%
r2_score = r2_score(y_test, y_pred)
r2_score
# Out:
# 0.98969880227651

# %%
mae = mean_absolute_error(y_test, y_pred)
mae
# Out:
# 3.8041319552540522

# %%
mse = mean_squared_error(y_test, y_pred)
mse
# Out:
# 46.97087470716438

# %%
rmse = np.sqrt(mean_squared_error(y_test, y_pred))
rmse
# Out:
# 6.853530090921348

# %%
sales_mean = df["CO2 Emissions(g/km)"].mean()
sales_mean
# Out:
# 250.58469871360867

# %%
mae / sales_mean
# Out:
# 0.015181022523652832

# %%
rmse / sales_mean
# Out:
# 0.027350153964325632

# %%
def eval_metric(actual, pred):
    mae = mean_absolute_error(actual, pred)
    mse = mean_squared_error(actual, pred)
    rmse = np.sqrt(mean_squared_error(actual, pred))
    R2_score = r2_score(actual, pred)
    print("Model testing performance: ")
    print("---------------------------")
    print(f"R2_score \t: {R2_score}")
    print(f"MAE \t\t: {mae}")
    print(f"MSE \t\t: {mse}")
    print(f"RMSE \t\t: {rmse}")

# %%
y_train_pred = model.predict(X_train)

# %%
eval_metric(y_train, y_train_pred)
# Out:
# Model testing performance:
# ---------------------------
# R2_score 	: 0.9895447791572398
# MAE 		: 3.5426807733669117
# MSE 		: 42.83926092614409
# RMSE 		: 6.545170809546844

# %%
eval_metric(y_test, y_pred)
# Out:
# Model testing performance:
# ---------------------------
# R2_score 	: 0.98969880227651
# MAE 		: 3.8041319552540522
# MSE 		: 46.97087470716438
# RMSE 		: 6.853530090921348

# %%
residuals = y_test - y_pred

# %%
plt.figure(figsize = (10, 6))
sns.scatterplot(x = y_test, y=residuals)
plt.axhline(y = 0, color = "r", linestyle = "--")
plt.show()

# %%
sns.kdeplot(residuals);

# %%
stats.probplot(residuals, dist = "norm", plot = plt);

# %%
skew(residuals)
# Out:
# 3.457928785754534

# %%
model = LinearRegression()
visualizer = ResidualsPlot(model)

visualizer.fit(X_train, y_train)  # Fit the training data to the visualizer
visualizer.score(X_test, y_test)  # Evaluate the model on the test data
visualizer.show();                # Finalize and render the figure

# %%
model = LinearRegression()
visualizer = PredictionError(model)

visualizer.fit(X_train, y_train)  
visualizer.score(X_test, y_test)  
visualizer.show();
